# %%
#IN THIS EDA WE GOING TO GET DETAILS OF MALE AND FEMALE MEET ROAD ACCIDENT.

#TOP 5 STATES BASED ON THEIR AGES LESS THAN 18, 18-25 YRS, 25-35 YRS, 35-45YRS, 45-60YRS,60 AND ABOVE IN INDIA MEET ROAD ACCIDENT.

#WHICH AGE GROUP MEETS HIGH NUMBER OF ROAD ACCIDENTS.

#LOWEST 5 STATES BASED ON THEIR AGES LESS THAN 18, 18-25 YRS, 25-35 YRS, 35-45YRS, 45-60YRS,60 AND ABOVE IN INDIA MEET ROAD ACCIDENT.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import plotly.express as px

# %%
df=pd.read_csv("/content/Road-Accidents-2018-Annexure-32 ages.csv") #importing csv file as dataframe
df
# Out:
#    Sl. No.                   State/UT  Less than 18 Years - Male  \
# 0        1             Andhra Pradesh                         43
# 1        2          Arunachal Pradesh                          7
# 2        3                      Assam                         27
# 3        4                      Bihar                          0
# 4        5               Chhattisgarh                         49
# 5        6                        Goa                          2
# 6        7                    Gujarat                         86
# 7        8                    Haryana                         96
# 8        9           Himachal Pradesh                         10
# 9       10            Jammu & Kashmir                         14
# 10      11                  Jharkhand                         68
# 11      12                  Karnataka                         47
# 12      13                     Kerala                         37
# ...

# %%
df.columns #columns in data frame
# Out:
# Index(['Sl. No.', 'State/UT', 'Less than 18 Years - Male',
#        'Less than 18 Years - Female', '18-25 Years - Male',
#        '18-25 Years - Female', '25-35 Years - Male', '25-35 Years - Female',
#        '35-45 Years - Male', '35-45 Years - Female', '45-60 Years - Male',
#        '45-60 Years - Female', '60 and Above - Male', '60 and Above - Female',
#        'Age not known - Male', 'Age not known - Female'],
#       dtype='object')

# %%
df.shape #dimension of dataframe
# Out:
# (37, 16)

# %%
df.info() #checking its data types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 16 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Sl. No.                      37 non-null     object
#  1   State/UT                     37 non-null     object
#  2   Less than 18 Years - Male    37 non-null     int64
#  3   Less than 18 Years - Female  37 non-null     int64
#  4   18-25 Years - Male           37 non-null     int64
#  5   18-25 Years - Female         37 non-null     int64
#  6   25-35 Years - Male           37 non-null     int64
#  7   25-35 Years - Female         37 non-null     int64
#  8   35-45 Years - Male           37 non-null     int64
#  9   35-45 Years - Female         37 non-null     int64
#  10  45-60 Years - Male           37 non-null     int64
#  11  45-60 Years - Female         37 non-null     int64
#  12  60 and Above - Male          37 non-null     int64
# ...

# %%
# To view some basic statistical details 

df.describe()
# Out:
#        Less than 18 Years - Male  Less than 18 Years - Female  \
# count                  37.000000                    37.000000
# mean                  107.027027                     8.486486
# std                   340.037946                    28.638185
# min                     0.000000                     0.000000
# 25%                     2.000000                     0.000000
# 50%                    14.000000                     0.000000
# 75%                    65.000000                     3.000000
# max                  1980.000000                   157.000000
#
#        18-25 Years - Male  18-25 Years - Female  25-35 Years - Male  \
# count           37.000000             37.000000           37.000000
# mean           760.756757             26.108108          883.459459
# std           2298.824306             81.498393         2665.605514
# min              0.000000              0.000000            0.000000
# ...

# %%
#  check for null value or not

df.isnull().sum()
# Out:
# Sl. No.                        0
# State/UT                       0
# Less than 18 Years - Male      0
# Less than 18 Years - Female    0
# 18-25 Years - Male             0
# 18-25 Years - Female           0
# 25-35 Years - Male             0
# 25-35 Years - Female           0
# 35-45 Years - Male             0
# 35-45 Years - Female           0
# 45-60 Years - Male             0
# 45-60 Years - Female           0
# 60 and Above - Male            0
# 60 and Above - Female          0
# Age not known - Male           0
# Age not known - Female         0
# dtype: int64

# %%
# checking a unique values in column

df.nunique()
# Out:
# Sl. No.                        37
# State/UT                       37
# Less than 18 Years - Male      26
# Less than 18 Years - Female    12
# 18-25 Years - Male             31
# 18-25 Years - Female           22
# 25-35 Years - Male             35
# 25-35 Years - Female           21
# 35-45 Years - Male             35
# 35-45 Years - Female           19
# 45-60 Years - Male             33
# 45-60 Years - Female           14
# 60 and Above - Male            24
# 60 and Above - Female           8
# Age not known - Male           20
# Age not known - Female          8
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# correlation heatmap
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(), annot = True, cmap='coolwarm')

# %%
# Visualizing dataset and also checking for outliers 

df.boxplot(figsize=(50,10),fontsize=25,rot=45)

# %%
total=df.tail(1)

# %%
total #to check total number of Male and Female accidents
# Out:
#    Sl. No. State/UT  Less than 18 Years - Male  Less than 18 Years - Female  \
# 36   Total    Total                       1980                          157
#
#     18-25 Years - Male  18-25 Years - Female  25-35 Years - Male  \
# 36               14074                   483               16344
#
#     25-35 Years - Female  35-45 Years - Male  35-45 Years - Female  \
# 36                   501               12344                   386
#
#     45-60 Years - Male  45-60 Years - Female  60 and Above - Male  \
# 36                7718                   208                 1929
#
#     60 and Above - Female  Age not known - Male  Age not known - Female
# 36                     61                  1483                      89

# %%
a=total

Male=0
Female=0

for key,values in a.iteritems():
   if key.endswith('Male'):
       Male=Male+values
   elif key.endswith('Female'):
       Female=Female+values
print("MALE ACCIDENT COUNT :",Male)
print("FEMALE ACCIDENT COUNT :",Female)
# Out:
# MALE ACCIDENT COUNT : 36    55872
# dtype: int64
# FEMALE ACCIDENT COUNT : 36    1885
# dtype: int64

# %%
male_female=pd.DataFrame({'sex':['Male','Female'],'Accident':[55872,1885]}) #got sum of male and female accidents
male_female
# Out:
#       sex  Accident
# 0    Male     55872
# 1  Female      1885

# %%
fig=go.Figure(data=[go.Pie(labels=male_female["sex"],values=male_female["Accident"],pull=[0.5,0,0])])
fig.update_layout(title_text="MALE & FEMALE ROAD ACCIDENT IN INDIA")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#SORTED FOR Less than 18 Years - Male meets Road accident
Less_18=df[['State/UT','Less than 18 Years - Male']] 
Less_18.sort_values(by="Less than 18 Years - Male",ascending=False,inplace=True)
Less_18.reset_index(drop=True,inplace=True)
Less_18=Less_18.drop(0)
Less_18
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                      State/UT  Less than 18 Years - Male
# 1               Uttar Pradesh                        744
# 2              Madhya Pradesh                        208
# 3                   Rajasthan                        117
# 4                     Haryana                         96
# 5                 Maharashtra                         90
# 6                     Gujarat                         86
# 7                   Jharkhand                         68
# 8                      Odisha                         67
# 9                  Tamil Nadu                         65
# 10                  Telangana                         55
# ...

# %%
top_less18=Less_18.head(5)

# %%
fig=px.bar(top_less18,x="State/UT",y='Less than 18 Years - Male',hover_name='State/UT',color_continuous_scale='blugrn',title='Top 5 States -Less than 18 Years - Male Meets Accident In India-2018',color='Less than 18 Years - Male')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
lowest_Less18=Less_18.tail(5)

# %%
fig=px.bar(lowest_Less18,x="State/UT",y='Less than 18 Years - Male',hover_name='State/UT',color_continuous_scale='blugrn',title='Lowest 5 States -Less than 18 Years - Male Meets Accident In India-2018',color='Less than 18 Years - Male')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#SORTED FOR Less than 18 Years -Female meets Road accident
Lessf_18=df[['State/UT','Less than 18 Years - Female']] 
Lessf_18.sort_values(by="Less than 18 Years - Female",ascending=False,inplace=True)
Lessf_18.reset_index(drop=True,inplace=True)

Lessf_18=Lessf_18.drop(0)
Lessf_18
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                      State/UT  Less than 18 Years - Female
# 1               Uttar Pradesh                           82
# 2                   Jharkhand                           23
# 3                 West Bengal                           10
# 4                 Maharashtra                            7
# 5                   Rajasthan                            6
# 6                     Haryana                            6
# 7                     Gujarat                            5
# 8              Andhra Pradesh                            4
# 9                      Punjab                            3
# 10             Madhya Pradesh                            2
# ...

# %%
Lessf_18.head()
# Out:
#         State/UT  Less than 18 Years - Female
# 1  Uttar Pradesh                           82
# 2      Jharkhand                           23
# 3    West Bengal                           10
# 4    Maharashtra                            7
# 5      Rajasthan                            6

# %%
Lessf_18.tail()
# Out:
#      State/UT  Less than 18 Years - Female
# 32    Mizoram                            0
# 33  Meghalaya                            0
# 34    Manipur                            0
# 35        Goa                            0
# 36   Nagaland                            0

# %%
top_Less18f=Lessf_18.head()

# %%
fig=px.bar(top_Less18f,x="State/UT",y='Less than 18 Years - Female',hover_name='State/UT',color_continuous_scale='speed',title='Top 5 States -Less than 18 Years - Female Meets Accident In India-2018',color='Less than 18 Years - Female')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
lowest_Less18f=Lessf_18.tail()

# %%
fig=px.bar(lowest_Less18f,x="State/UT",y='Less than 18 Years - Female',hover_name='State/UT',color_continuous_scale='speed',title='Lowest 5 States -Less than 18 Years - Female Meets Accident In India-2018',color='Less than 18 Years - Female')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#SORTED FOR 18-25 Years Male meets Road accident
M_18_25=df[['State/UT','18-25 Years - Male']] 
M_18_25.sort_values(by="18-25 Years - Male",ascending=False,inplace=True)
M_18_25.reset_index(drop=True,inplace=True)

M_18_25=M_18_25.drop(0)
M_18_25
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                      State/UT  18-25 Years - Male
# 1               Uttar Pradesh                2040
# 2                   Rajasthan                1275
# 3                 Maharashtra                1255
# 4                   Karnataka                1072
# 5                  Tamil Nadu                 949
# 6              Madhya Pradesh                 936
# 7                     Gujarat                 679
# 8                   Jharkhand                 657
# 9                       Bihar                 611
# 10               Chhattisgarh                 584
# 11             Andhra Pradesh                 563
# 12                  Telangana                 562
# ...

# %%
M_18_25.head()
# Out:
#         State/UT  18-25 Years - Male
# 1  Uttar Pradesh                2040
# 2      Rajasthan                1275
# 3    Maharashtra                1255
# 4      Karnataka                1072
# 5     Tamil Nadu                 949

# %%
M_18_25.tail()
# Out:
#                      State/UT  18-25 Years - Male
# 32  Andaman & Nicobar Islands                   2
# 33                     Sikkim                   2
# 34                   Nagaland                   2
# 35                Lakshadweep                   0
# 36                    Mizoram                   0

# %%
top_male_18_25=M_18_25.head()

# %%
fig=px.bar(top_male_18_25,x="State/UT",y='18-25 Years - Male',hover_name='State/UT',color_continuous_scale='turbo',title='Top 5 States -18-25 Years - Male Meets Accident In India-2018',color='18-25 Years - Male')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
lowest_male_18_25=M_18_25.tail()

# %%
fig=px.bar(lowest_male_18_25,x="State/UT",y='18-25 Years - Male',hover_name='State/UT',color_continuous_scale='turbo',title='Lowest 5 States -18-25 Years - Male Meets Accident In India-2018',color='18-25 Years - Male')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#SORTED FOR18-25 Years-Female meets Road accident
F_18_25=df[['State/UT','18-25 Years - Female']] 
F_18_25.sort_values(by="18-25 Years - Female",ascending=False,inplace=True)
F_18_25.reset_index(drop=True,inplace=True)

F_18_25=F_18_25.drop(0)
F_18_25
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                      State/UT  18-25 Years - Female
# 1               Uttar Pradesh                   152
# 2                      Punjab                    44
# 3                  Tamil Nadu                    42
# 4                 Maharashtra                    30
# 5                   Rajasthan                    26
# 6              Andhra Pradesh                    23
# 7                   Jharkhand                    20
# 8                     Gujarat                    18
# 9                   Karnataka                    17
# 10               Chhattisgarh                    17
# 11                  Telangana                    15
# ...

# %%
F_18_25
# Out:
#                      State/UT  18-25 Years - Female
# 1               Uttar Pradesh                   152
# 2                      Punjab                    44
# 3                  Tamil Nadu                    42
# 4                 Maharashtra                    30
# 5                   Rajasthan                    26
# 6              Andhra Pradesh                    23
# 7                   Jharkhand                    20
# 8                     Gujarat                    18
# 9                   Karnataka                    17
# 10               Chhattisgarh                    17
# 11                  Telangana                    15
# 12                      Assam                    13
# 13                    Haryana                    11
# 14                     Odisha                    10
# 15             Madhya Pradesh                     8
# 16                      Delhi                     7
# 17                     Kerala                     6
# ...

# %%
F_18_25.head()
# Out:
#         State/UT  18-25 Years - Female
# 1  Uttar Pradesh                   152
# 2         Punjab                    44
# 3     Tamil Nadu                    42
# 4    Maharashtra                    30
# 5      Rajasthan                    26

# %%
Top_Female_18_25=F_18_25.head()

# %%
F_18_25.tail()
# Out:
#        State/UT  18-25 Years - Female
# 32      Mizoram                     0
# 33  Daman & Diu                     0
# 34  Lakshadweep                     0
# 35   Puducherry                     0
# 36     Nagaland                     0

# %%
Lowest_f_18_25=F_18_25.tail()

# %%
fig=px.bar(Top_Female_18_25,x="State/UT",y='18-25 Years - Female',hover_name='State/UT',color_continuous_scale='dense',title='Top 5 States 18-25 Years - Female- Meets Accident In India-2018',color='18-25 Years - Female')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=px.bar(Lowest_f_18_25,x="State/UT",y='18-25 Years - Female',hover_name='State/UT',color_continuous_scale='dense',title='Lowest 5 States 18-25 Years - Female- Meets Accident In India-2018',color='18-25 Years - Female')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#SORTED FOR 25-35 Years - Male meets Road accident
M_25_35=df[['State/UT','25-35 Years - Male']] 
M_25_35.sort_values(by="25-35 Years - Male",ascending=False,inplace=True)
M_25_35.reset_index(drop=True,inplace=True)
M_25_35=M_25_35.drop(0)
M_25_35
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                      State/UT  25-35 Years - Male
# 1               Uttar Pradesh                1853
# 2                 Maharashtra                1653
# 3                   Karnataka                1419
# 4                   Rajasthan                1398
# 5              Madhya Pradesh                1270
# 6                  Tamil Nadu                1178
# 7                     Gujarat                 883
# 8                Chhattisgarh                 822
# 9                   Telangana                 776
# 10             Andhra Pradesh                 774
# 11                     Odisha                 589
# 12                     Punjab                 554
# ...

# %%
M_25_35.head()
# Out:
#          State/UT  25-35 Years - Male
# 1   Uttar Pradesh                1853
# 2     Maharashtra                1653
# 3       Karnataka                1419
# 4       Rajasthan                1398
# 5  Madhya Pradesh                1270

# %%
M_25_35.tail()
# Out:
#                      State/UT  25-35 Years - Male
# 32                   Nagaland                   4
# 33                    Mizoram                   3
# 34  Andaman & Nicobar Islands                   2
# 35                     Sikkim                   1
# 36                Lakshadweep                   0

# %%
Top_M_25_35=M_25_35.head()
Lowest_M_25_35=M_25_35.tail()

# %%
fig=px.bar(Top_M_25_35,x="State/UT",y='25-35 Years - Male',hover_name='State/UT',color_continuous_scale='algae',title='Top 5 States 25-35 Years - Male- Meets Accident In India-2018',color='25-35 Years - Male')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=px.bar(Lowest_M_25_35,x="State/UT",y='25-35 Years - Male',hover_name='State/UT',color_continuous_scale='algae',title='Lowest 5 States 25-35 Years - Male- Meets Accident In India-2018',color='25-35 Years - Male')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#SORTED  25-35 Years  -Female meets Road accident
F_25_35=df[['State/UT','25-35 Years - Female']] 
F_25_35.sort_values(by="25-35 Years - Female",ascending=False,inplace=True)
F_25_35.reset_index(drop=True,inplace=True)

F_25_35=F_25_35.drop(0)
F_25_35
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                      State/UT  25-35 Years - Female
# 1               Uttar Pradesh                   116
# 2                  Tamil Nadu                    64
# 3                      Punjab                    56
# 4                 Maharashtra                    45
# 5                   Rajasthan                    27
# 6                     Gujarat                    27
# 7                   Jharkhand                    22
# 8              Andhra Pradesh                    20
# 9              Madhya Pradesh                    16
# 10                West Bengal                    15
# 11               Chhattisgarh                    14
# ...

# %%
F_25_35.head()
# Out:
#         State/UT  25-35 Years - Female
# 1  Uttar Pradesh                   116
# 2     Tamil Nadu                    64
# 3         Punjab                    56
# 4    Maharashtra                    45
# 5      Rajasthan                    27

# %%
F_25_35.tail()
# Out:
#            State/UT  25-35 Years - Female
# 32      Daman & Diu                     0
# 33          Mizoram                     0
# 34      Lakshadweep                     0
# 35          Manipur                     0
# 36  Jammu & Kashmir                     0

# %%
Top_F_25_35=F_25_35.head()
Lowest_F_25_35=F_25_35.tail()

# %%
fig=px.bar(Top_F_25_35,x="State/UT",y='25-35 Years - Female',hover_name='State/UT',color_continuous_scale='brwnyl',title='Top 5 States 25-35 Years - Female- Meets Accident In India-2018',color='25-35 Years - Female')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=px.bar(Lowest_F_25_35,x="State/UT",y='25-35 Years - Female',hover_name='State/UT',color_continuous_scale='brwnyl',title='Lowest 5 States 25-35 Years - Female Meets Accident In India-2018',color='25-35 Years - Female')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#SORTED FOR 35-45 Years - Male meets Road accident
M_35_45=df[['State/UT','35-45 Years - Male']] 
M_35_45.sort_values(by="35-45 Years - Male",ascending=False,inplace=True)
M_35_45.reset_index(drop=True,inplace=True)
M_35_45=M_35_45.drop(0)
M_35_45
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                      State/UT  35-45 Years - Male
# 1               Uttar Pradesh                1509
# 2                 Maharashtra                1392
# 3                  Tamil Nadu                1121
# 4                   Karnataka                1032
# 5                   Rajasthan                 994
# 6              Madhya Pradesh                 812
# 7              Andhra Pradesh                 800
# 8                     Gujarat                 670
# 9                   Telangana                 606
# 10               Chhattisgarh                 441
# 11                     Punjab                 429
# 12                     Odisha                 399
# ...

# %%
M_35_45.head()
# Out:
#         State/UT  35-45 Years - Male
# 1  Uttar Pradesh                1509
# 2    Maharashtra                1392
# 3     Tamil Nadu                1121
# 4      Karnataka                1032
# 5      Rajasthan                 994

# %%
M_35_45.tail()
# Out:
#                      State/UT  35-45 Years - Male
# 32                     Sikkim                   2
# 33                    Mizoram                   2
# 34                   Nagaland                   2
# 35  Andaman & Nicobar Islands                   1
# 36                Lakshadweep                   0

# %%
Top_M_35_45=M_35_45.head()

Lowest_M_35_45=M_35_45.tail()

# %%
fig=px.bar(Top_M_35_45,x="State/UT",y='35-45 Years - Male',hover_name='State/UT',color_continuous_scale='amp',title='Top 5 States 35-45 Years - Male- Meets Accident In India-2018',color='35-45 Years - Male')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=px.bar(Lowest_M_35_45,x="State/UT",y='35-45 Years - Male',hover_name='State/UT',color_continuous_scale='amp',title='Lowest 5 States 35-45 Years - Male- Meets Accident In India-2018',color='35-45 Years - Male')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#SORTED  35_45 Years  -Female meets Road accident
F_35_45=df[['State/UT','35-45 Years - Female']] 
F_35_45.sort_values(by="35-45 Years - Female",ascending=False,inplace=True)
F_35_45.reset_index(drop=True,inplace=True)

F_35_45=F_35_45.drop(0)
F_35_45
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                      State/UT  35-45 Years - Female
# 1               Uttar Pradesh                    80
# 2                  Tamil Nadu                    49
# 3                      Punjab                    48
# 4              Andhra Pradesh                    30
# 5                 West Bengal                    23
# 6                     Gujarat                    22
# 7                 Maharashtra                    20
# 8                   Jharkhand                    19
# 9                      Kerala                    19
# 10             Madhya Pradesh                    10
# 11               Chhattisgarh                     9
# ...

# %%
F_35_45.head()
# Out:
#          State/UT  35-45 Years - Female
# 1   Uttar Pradesh                    80
# 2      Tamil Nadu                    49
# 3          Punjab                    48
# 4  Andhra Pradesh                    30
# 5     West Bengal                    23

# %%
F_35_45.tail()
# Out:
#                 State/UT  35-45 Years - Female
# 32  Dadra & Nagar Haveli                     0
# 33           Daman & Diu                     0
# 34      Himachal Pradesh                     0
# 35           Lakshadweep                     0
# 36              Nagaland                     0

# %%
Top_F_35_45=F_35_45.head()

Lowest_F_35_45=F_35_45.tail()

# %%
fig=px.bar(Top_F_35_45,x="State/UT",y='35-45 Years - Female',hover_name='State/UT',color_continuous_scale='Mint',title='Top 5 States 35-45 Years - Female- Meets Accident In India-2018',color='35-45 Years - Female')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=px.bar(Lowest_F_35_45,x="State/UT",y='35-45 Years - Female',hover_name='State/UT',color_continuous_scale='Mint',title='Lowest 5 States 35-45 Years - Female- Meets Accident In India-2018',color='35-45 Years - Female')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#SORTED FOR 45-60 Years- Male meets Road accident
M_45_60=df[['State/UT','45-60 Years - Male']] 
M_45_60.sort_values(by="45-60 Years - Male",ascending=False,inplace=True)
M_45_60.reset_index(drop=True,inplace=True)
M_45_60=M_45_60.drop(0)
M_45_60
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                      State/UT  45-60 Years - Male
# 1                 Maharashtra                 955
# 2               Uttar Pradesh                 934
# 3                  Tamil Nadu                 851
# 4                   Karnataka                 609
# 5              Andhra Pradesh                 556
# 6                   Telangana                 421
# 7              Madhya Pradesh                 403
# 8                      Kerala                 398
# 9                     Gujarat                 391
# 10                  Rajasthan                 333
# 11                     Punjab                 307
# 12                     Odisha                 225
# ...

# %%
M_45_60.head()
# Out:
#          State/UT  45-60 Years - Male
# 1     Maharashtra                 955
# 2   Uttar Pradesh                 934
# 3      Tamil Nadu                 851
# 4       Karnataka                 609
# 5  Andhra Pradesh                 556

# %%
M_45_60.tail()
# Out:
#                      State/UT  45-60 Years - Male
# 32                     Sikkim                   1
# 33                    Tripura                   1
# 34                    Mizoram                   0
# 35  Andaman & Nicobar Islands                   0
# 36                Lakshadweep                   0

# %%
Top_M_45_60=M_45_60.head()

Lowest_M_45_60=M_45_60.tail()

# %%
fig=px.bar(Top_M_45_60,x="State/UT",y='45-60 Years - Male',hover_name='State/UT',color_continuous_scale='Mint',title='Top 5 States 45-60 Years - Male- Meets Accident In India-2018',color='45-60 Years - Male')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=px.bar(Lowest_M_45_60,x="State/UT",y='45-60 Years - Male',hover_name='State/UT',color_continuous_scale='Mint',title='Lowest 5 States 45-60 Years - Male- Meets Accident In India-2018',color='45-60 Years - Male')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#SORTED  45-60 Years -Female meets Road accident
F_45_60=df[['State/UT','45-60 Years - Female']] 
F_45_60.sort_values(by="45-60 Years - Female",ascending=False,inplace=True)
F_45_60.reset_index(drop=True,inplace=True)

F_45_60=F_45_60.drop(0)
F_45_60
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                      State/UT  45-60 Years - Female
# 1               Uttar Pradesh                    36
# 2                  Tamil Nadu                    34
# 3                      Punjab                    26
# 4                   Jharkhand                    19
# 5              Andhra Pradesh                    14
# 6                     Gujarat                    12
# 7                 Maharashtra                    12
# 8                      Kerala                     9
# 9                 West Bengal                     8
# 10                    Haryana                     8
# 11             Madhya Pradesh                     5
# ...

# %%
F_45_60.head()
# Out:
#          State/UT  45-60 Years - Female
# 1   Uttar Pradesh                    36
# 2      Tamil Nadu                    34
# 3          Punjab                    26
# 4       Jharkhand                    19
# 5  Andhra Pradesh                    14

# %%
F_45_60.tail()
# Out:
#              State/UT  45-60 Years - Female
# 32    Jammu & Kashmir                     0
# 33  Arunachal Pradesh                     0
# 34            Mizoram                     0
# 35            Manipur                     0
# 36           Nagaland                     0

# %%
Top_F_45_60=F_45_60.head()

Lowest_F_45_60=F_45_60.tail()

# %%
fig=px.bar(Top_F_45_60,x="State/UT",y='45-60 Years - Female',hover_name='State/UT',color_continuous_scale='burgyl',title='Top 5 States 45-60 Years - Female - Meets Accident In India-2018',color='45-60 Years - Female')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=px.bar(Lowest_F_45_60,x="State/UT",y='45-60 Years - Female',hover_name='State/UT',color_continuous_scale='burgyl',title='Lowest 5 States 45-60 Years - Female- Meets Accident In India-2018',color='45-60 Years - Female')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#SORTED FOR 60 and Above - Male meets Road accident
M_60=df[['State/UT','60 and Above - Male']] 
M_60.sort_values(by="60 and Above - Male",ascending=False,inplace=True)
M_60.reset_index(drop=True,inplace=True)
M_60=M_60.drop(0)
M_60
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                      State/UT  60 and Above - Male
# 1               Uttar Pradesh                  289
# 2                  Tamil Nadu                  289
# 3                      Kerala                  215
# 4                 Maharashtra                  204
# 5              Madhya Pradesh                  142
# 6              Andhra Pradesh                  134
# 7                   Karnataka                  131
# 8                   Telangana                  126
# 9                     Haryana                   88
# 10                    Gujarat                   72
# 11                     Punjab                   43
# ...

# %%
M_60.head()
# Out:
#          State/UT  60 and Above - Male
# 1   Uttar Pradesh                  289
# 2      Tamil Nadu                  289
# 3          Kerala                  215
# 4     Maharashtra                  204
# 5  Madhya Pradesh                  142

# %%
M_60.tail()
# Out:
#              State/UT  60 and Above - Male
# 32  Arunachal Pradesh                    0
# 33            Mizoram                    0
# 34          Meghalaya                    0
# 35       Chhattisgarh                    0
# 36           Nagaland                    0

# %%
Top_M_60=M_60.head()
Lowest_M_60=M_60.tail()

# %%
fig=px.bar(Top_M_60,x="State/UT",y='60 and Above - Male',hover_name='State/UT',color_continuous_scale='burgyl',title='Top 5 States 60 and Above - Male- Meets Accident In India-2018',color='60 and Above - Male')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=px.bar(Lowest_M_60,x="State/UT",y='60 and Above - Male',hover_name='State/UT',color_continuous_scale='burgyl',title='Lowest 5 States 60 and Above - Male- Meets Accident In India-2018',color='60 and Above - Male')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#SORTED  60 and Above-Female meets Road accident
F_60=df[['State/UT','60 and Above - Female']] 
F_60.sort_values(by="60 and Above - Female",ascending=False,inplace=True)
F_60.reset_index(drop=True,inplace=True)

F_60=F_60.drop(0)
F_60
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                      State/UT  60 and Above - Female
# 1               Uttar Pradesh                     24
# 2                      Punjab                      9
# 3                  Tamil Nadu                      6
# 4              Andhra Pradesh                      6
# 5                      Kerala                      5
# 6                 Maharashtra                      2
# 7                     Haryana                      2
# 8                  Puducherry                      2
# 9                     Gujarat                      2
# 10                  Telangana                      2
# 11             Madhya Pradesh                      1
# ...

# %%
F_60.head()
# Out:
#          State/UT  60 and Above - Female
# 1   Uttar Pradesh                     24
# 2          Punjab                      9
# 3      Tamil Nadu                      6
# 4  Andhra Pradesh                      6
# 5          Kerala                      5

# %%
F_60.tail()
# Out:
#             State/UT  60 and Above - Female
# 32         Karnataka                      0
# 33         Jharkhand                      0
# 34   Jammu & Kashmir                      0
# 35  Himachal Pradesh                      0
# 36          Nagaland                      0

# %%
Top_F_60=F_60.head()

Lowest_F_60=F_60.tail()

# %%
fig=px.bar(Top_F_60,x="State/UT",y='60 and Above - Female',hover_name='State/UT',color_continuous_scale='burgyl',title='Top 5 States-60 and Above - Female Meets Accident In India-2018',color='60 and Above - Female')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=px.bar(Lowest_F_60,x="State/UT",y='60 and Above - Female',hover_name='State/UT',color_continuous_scale='burgyl',title='Lowest 5 States 60 and Above - Female Meets Accident In India-2018',color='60 and Above - Female')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#SORTED Age not known - Male meets Road accident
M=df[['State/UT','Age not known - Male']] 
M.sort_values(by="Age not known - Male",ascending=False,inplace=True)
M.reset_index(drop=True,inplace=True)
M=M.drop(0)
M
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                      State/UT  Age not known - Male
# 1               Uttar Pradesh                   427
# 2                 West Bengal                   247
# 3                   Jharkhand                   154
# 4                     Haryana                   138
# 5                 Maharashtra                   118
# 6                     Gujarat                   116
# 7                      Odisha                    62
# 8              Madhya Pradesh                    48
# 9                      Punjab                    45
# 10               Chhattisgarh                    34
# 11                  Rajasthan                    22
# ...

# %%
M.head()
# Out:
#         State/UT  Age not known - Male
# 1  Uttar Pradesh                   427
# 2    West Bengal                   247
# 3      Jharkhand                   154
# 4        Haryana                   138
# 5    Maharashtra                   118

# %%
M.tail()
# Out:
#              State/UT  Age not known - Male
# 32          Telangana                     0
# 33   Himachal Pradesh                     0
# 34          Karnataka                     0
# 35  Arunachal Pradesh                     0
# 36        Uttarakhand                     0

# %%
#SORTED Age not known - Female meets Road accident
F=df[['State/UT','Age not known - Female']] 
F.sort_values(by="Age not known - Female",ascending=False,inplace=True)
F.reset_index(drop=True,inplace=True)
F=F.drop(0)
F
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                      State/UT  Age not known - Female
# 1                 West Bengal                      41
# 2                   Jharkhand                      19
# 3               Uttar Pradesh                      18
# 4                 Maharashtra                       3
# 5                       Delhi                       2
# 6                     Haryana                       2
# 7                      Punjab                       1
# 8             Jammu & Kashmir                       1
# 9                 Uttarakhand                       1
# 10               Chhattisgarh                       1
# 11                 Tamil Nadu                       0
# ...

# %%
F.head()
# Out:
#         State/UT  Age not known - Female
# 1    West Bengal                      41
# 2      Jharkhand                      19
# 3  Uttar Pradesh                      18
# 4    Maharashtra                       3
# 5          Delhi                       2

# %%
F.tail()
# Out:
#     State/UT  Age not known - Female
# 32   Gujarat                       0
# 33       Goa                       0
# 34     Bihar                       0
# 35     Assam                       0
# 36  Nagaland                       0

# %%
a=df.iloc[-1:]
a
# Out:
#    Sl. No. State/UT  Less than 18 Years - Male  Less than 18 Years - Female  \
# 36   Total    Total                       1980                          157
#
#     18-25 Years - Male  18-25 Years - Female  25-35 Years - Male  \
# 36               14074                   483               16344
#
#     25-35 Years - Female  35-45 Years - Male  35-45 Years - Female  \
# 36                   501               12344                   386
#
#     45-60 Years - Male  45-60 Years - Female  60 and Above - Male  \
# 36                7718                   208                 1929
#
#     60 and Above - Female  Age not known - Male  Age not known - Female
# 36                     61                  1483                      89

# %%
a.columns
# Out:
# Index(['Sl. No.', 'State/UT', 'Less than 18 Years - Male',
#        'Less than 18 Years - Female', '18-25 Years - Male',
#        '18-25 Years - Female', '25-35 Years - Male', '25-35 Years - Female',
#        '35-45 Years - Male', '35-45 Years - Female', '45-60 Years - Male',
#        '45-60 Years - Female', '60 and Above - Male', '60 and Above - Female',
#        'Age not known - Male', 'Age not known - Female'],
#       dtype='object')

# %%
s=a.loc[36]
a=pd.DataFrame(s)
a
# Out:
#                                 36
# Sl. No.                      Total
# State/UT                     Total
# Less than 18 Years - Male     1980
# Less than 18 Years - Female    157
# 18-25 Years - Male           14074
# 18-25 Years - Female           483
# 25-35 Years - Male           16344
# 25-35 Years - Female           501
# 35-45 Years - Male           12344
# 35-45 Years - Female           386
# 45-60 Years - Male            7718
# 45-60 Years - Female           208
# 60 and Above - Male           1929
# 60 and Above - Female           61
# Age not known - Male          1483
# Age not known - Female          89

# %%
a
# Out:
#                                 36
# Sl. No.                      Total
# State/UT                     Total
# Less than 18 Years - Male     1980
# Less than 18 Years - Female    157
# 18-25 Years - Male           14074
# 18-25 Years - Female           483
# 25-35 Years - Male           16344
# 25-35 Years - Female           501
# 35-45 Years - Male           12344
# 35-45 Years - Female           386
# 45-60 Years - Male            7718
# 45-60 Years - Female           208
# 60 and Above - Male           1929
# 60 and Above - Female           61
# Age not known - Male          1483
# Age not known - Female          89

# %%
a.rename({36:'vals'},axis=1,inplace=True)
# f=a.iloc[1]
# def f

# %%
a.reset_index(inplace=True)#State/UT

# %%
a=a.iloc[2:,]
a
# Out:
#                           index   vals
# 2     Less than 18 Years - Male   1980
# 3   Less than 18 Years - Female    157
# 4            18-25 Years - Male  14074
# 5          18-25 Years - Female    483
# 6            25-35 Years - Male  16344
# 7          25-35 Years - Female    501
# 8            35-45 Years - Male  12344
# 9          35-45 Years - Female    386
# 10           45-60 Years - Male   7718
# 11         45-60 Years - Female    208
# 12          60 and Above - Male   1929
# 13        60 and Above - Female     61
# 14         Age not known - Male   1483
# 15       Age not known - Female     89

# %%
a.reset_index(inplace=True,drop=True)

# %%
a.rename({'State/UT':'Age'},axis=1,inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5047: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
a.sort_values(by='vals',ascending=False,inplace=True)
a.reset_index(drop=True,inplace=True)
# a.drop(['level_0'],axis=1,inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
a #AGE GROUP MEETS NUMBER OF ACCIDENTS IN INDIA
# Out:
#                             Age   vals
# 0            25-35 Years - Male  16344
# 1            18-25 Years - Male  14074
# 2            35-45 Years - Male  12344
# 3            45-60 Years - Male   7718
# 4     Less than 18 Years - Male   1980
# 5           60 and Above - Male   1929
# 6          Age not known - Male   1483
# 7          25-35 Years - Female    501
# 8          18-25 Years - Female    483
# 9          35-45 Years - Female    386
# 10         45-60 Years - Female    208
# 11  Less than 18 Years - Female    157
# 12       Age not known - Female     89
# 13        60 and Above - Female     61

# %%
# Set the width and height of the figure 
plt.figure(figsize=(10,6))
plt.title("AGE GROUP MEETS NUMBER OF ACCIDENTS IN INDIA-2018")
sns.barplot(x=a.vals,y=a['Age'])

# %%
#USING MATPLOTLIB
fig=px.bar(a,x="Age",y="vals",color='vals',color_continuous_scale='ice',hover_name='Age',title='AGE GROUP MEETS NUMBER OF ACCIDENTS IN INDIA-2018')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
